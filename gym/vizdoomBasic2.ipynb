# %% [markdown]
# # Vizdoom Defend Center

# %%
# !pip install vizdoom

# %%
# !cd github & git clone https://github.com/mwydmuch/ViZDoom

# %%
import sys
print(sys.path)
sys.path.append('C:\\Users\\joshu\\anaconda3\\lib\\site-packages\\vizdoom')
print(sys.path)

# %% [markdown]
# ### Get vizdoom running

# %%
#import vizoom for game environment
from vizdoom import *

# Import rand
import random

# Import time for sleeping
import time

# Import for identity matrix
import numpy as np

# %%
# setup game
game = DoomGame()
game.load_config('../../s22-team5-project/env/basic.cfg')
game.init()

# %%
# Actions we can take in the env
actions = np.identity(3, dtype=np.uint8)

# %%
# move left, move right, attack
actions
# Out:
# array([[1, 0, 0],
#        [0, 1, 0],
#        [0, 0, 1]], dtype=uint8)

# %%
episodes = 3
for episode in range(episodes):
    game.new_episode()
    while not game.is_episode_finished():
        state = game.get_state()
        img = state.screen_buffer # gets each image frame
        info = state.game_variables # amounts to ammo in this map
        reward = game.make_action(random.choice(actions),4) # frame skip so that the agent can see what he did
        print('reward: ', reward)
        time.sleep(0.02)
    print('result: ', game.get_total_reward())
    time.sleep(2)
# Out:
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  99.0
# result:  71.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  99.0
# result:  87.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  99.0
# result:  -142.0

# %%
game.close()

# %% [markdown]
# ### Connect to OpenAI Gym

# %%
# !pip install gym

# %% [markdown]
# import **Spacers**: the way we define shapes within the environment
# - box: arrays of any shape
# - discrete: set of discrete binary actions

# %%
# Import env base class from openAI gym
from gym import Env

# Import gym spaces
from gym.spaces import Discrete, Box

# Import opencv
import cv2

# %%
obsv_shape = game.get_state().screen_buffer.shape
obsv_shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_52772/1232784059.py in <module>
# ----> 1 obsv_shape = game.get_state().screen_buffer.shape
#       2 obsv_shape
#
# AttributeError: 'NoneType' object has no attribute 'screen_buffer'

# %%
actions.shape
# Out:
# (3, 3)

# %%
# Create vizdoom OpenAI Gym Environment
class VizDoomGym(Env):
    # function that is called at start of env
    def __init__(self, render=False):
        # Inherit from Env
        super().__init__()
        self.game = DoomGame()
        self.game.load_config('../../s22-team5-project/env/basic.cfg')
        
        # Choose whether or not to render each frame
        self.game.set_window_visible(render)
        self.game.init()
        
        # Create the obsv and action space
        self.observation_space = Box(low=0, high=255, 
                                     shape=(100,160,1), 
                                     dtype=np.uint8)
        self.action_space = Discrete(actions.shape[0])
    
    # How we take a step in the env
    def step(self, action):
        # Specify action and take step
        actions = np.identity(3, dtype=np.uint8)
        reward = self.game.make_action(actions[action], 4)
        
        # Get the other stuff
        if self.game.get_state():
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            ammo = self.game.get_state().game_variables[0]
        else:
            state = np.zeros(self.observation_space.shape)
            ammo = 0
        
        info = {"ammo":ammo}
        done = self.game.is_episode_finished()
        
        return state, reward, done, info
    
    # Predefined in Vizdoom, how to render the game
    def render():
        pass
    
    # What happens when we start a new game
    def reset(self):
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state)
    
    # Grayscale the frame and resize
    def grayscale(self, observation):
        # moves the color channels to the end of the shape
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY) 
        resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100,160,1))
        return state
        
    # Call to close down the game
    def close(self):
        self.game.close()

# %%
env = VizDoomGym(render=True)

# %%
state = env.reset()

# %%
state = env.step(0)

# %%
env.close()

# %%
# Import Env checker
from stable_baselines3.common import env_checker

# %%
env_checker.check_env(env)

# %% [markdown]
# ### View environment view state
# Need matplot in order to see the grayscaled frames

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\joshu\anaconda3\lib\site-packages (3.4.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\joshu\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\joshu\anaconda3\lib\site-packages (from matplotlib) (8.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\joshu\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: numpy>=1.16 in c:\users\joshu\anaconda3\lib\site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\joshu\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\joshu\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: six in c:\users\joshu\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(cv2.cvtColor(state, cv2.COLOR_BGR2RGB))

# %%
env.close()

# %% [markdown]
# ### Setup Callback

# %%
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113

# %%
# !pip install stable-baselines3[extra]

# %%
# Import os for file navigation
import os

# Import callback class from sb3
from stable_baselines3.common.callbacks import BaseCallback

# %%
# This class was taken from Nicholas Renotte for backing-up a model during training
#     (It is optional and is not needed to run the model)
class TrainAndLoggingCallback(BaseCallback):
    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path
        
    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)
            
    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)
                                                                             
        return True

# %%
CHECKPOINT_DIR = './train/train_basic2'
LOG_DIR = './logs/log_basic2'

# %%
callback = TrainAndLoggingCallback(check_freq=10000, 
                                   save_path=CHECKPOINT_DIR)

# %% [markdown]
# ### Training time baby

# %%
# Import ppo for training (RLA)
from stable_baselines3 import PPO

# %%
# Non-rendered environment
env = VizDoomGym()

# %%
model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1,
            learning_rate=0.0001, n_steps=2048)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Logging to ./logs/log_basic2\PPO_2
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.9     |
# |    ep_rew_mean     | -78.1    |
# | time/              |          |
# |    fps             | 11       |
# |    iterations      | 1        |
# |    time_elapsed    | 180      |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31          |
# |    ep_rew_mean          | -71.6       |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 2           |
# |    time_elapsed         | 373         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012765203 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.000262    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 572         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | 0.00217     |
# |    value_loss           | 2.26e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.2        |
# |    ep_rew_mean          | -42.6       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 3           |
# |    time_elapsed         | 557         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.018320195 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.357       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 971         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | 0.00241     |
# |    value_loss           | 2.5e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.3        |
# |    ep_rew_mean          | -50.1       |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 4           |
# |    time_elapsed         | 760         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013751955 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.425       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.91e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.00265     |
# |    value_loss           | 3.36e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 21.7       |
# |    ep_rew_mean          | -25.9      |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 5          |
# |    time_elapsed         | 955        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.51326126 |
# |    clip_fraction        | 0.442      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.487      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.82e+03   |
# |    n_updates            | 40         |
# |    policy_gradient_loss | 0.0386     |
# |    value_loss           | 3.05e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.5        |
# |    ep_rew_mean          | -40.9       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 6           |
# |    time_elapsed         | 1112        |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.021411179 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 0.639       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.08e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.0125      |
# |    value_loss           | 3.16e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.8        |
# |    ep_rew_mean          | 13.4        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 7           |
# |    time_elapsed         | 1249        |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011681434 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | 0.672       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.6e+03     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.004       |
# |    value_loss           | 3.16e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.6        |
# |    ep_rew_mean          | -8.83       |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 8           |
# |    time_elapsed         | 1390        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011219626 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.785      |
# |    explained_variance   | 0.692       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.49e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.00495     |
# |    value_loss           | 3.91e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.7        |
# |    ep_rew_mean          | -36.3       |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 9           |
# |    time_elapsed         | 1521        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.013524048 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.78       |
# |    explained_variance   | 0.696       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.67e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.00405     |
# |    value_loss           | 3.3e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 15.6       |
# |    ep_rew_mean          | 12.5       |
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 10         |
# |    time_elapsed         | 1673       |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.08142022 |
# |    clip_fraction        | 0.411      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.837     |
# |    explained_variance   | 0.704      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.43e+03   |
# |    n_updates            | 90         |
# |    policy_gradient_loss | 0.0158     |
# |    value_loss           | 2.04e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 21.1       |
# |    ep_rew_mean          | -21.7      |
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 11         |
# |    time_elapsed         | 1810       |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01814545 |
# |    clip_fraction        | 0.115      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.441     |
# |    explained_variance   | 0.756      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.29e+03   |
# |    n_updates            | 100        |
# |    policy_gradient_loss | 0.0108     |
# |    value_loss           | 2.41e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.2        |
# |    ep_rew_mean          | 44.9        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 12          |
# |    time_elapsed         | 1959        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.056487173 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.544      |
# |    explained_variance   | 0.736       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 819         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.0157      |
# |    value_loss           | 2.68e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.2        |
# |    ep_rew_mean          | -9.55       |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 13          |
# |    time_elapsed         | 2095        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.041344956 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.552      |
# |    explained_variance   | 0.704       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 870         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.00832     |
# |    value_loss           | 2.26e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.4        |
# |    ep_rew_mean          | 3.23        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 14          |
# |    time_elapsed         | 2241        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.018729318 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.376      |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 536         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.00977     |
# |    value_loss           | 2.08e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 21.9       |
# |    ep_rew_mean          | -34.2      |
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 15         |
# |    time_elapsed         | 2377       |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.19475305 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.413     |
# |    explained_variance   | 0.773      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.02e+03   |
# |    n_updates            | 140        |
# |    policy_gradient_loss | 0.00913    |
# |    value_loss           | 2e+03      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.8        |
# |    ep_rew_mean          | 18.4        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 16          |
# |    time_elapsed         | 2513        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010173801 |
# |    clip_fraction        | 0.0765      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.195      |
# |    explained_variance   | 0.732       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.25e+03    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00767     |
# |    value_loss           | 2.51e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23.5         |
# |    ep_rew_mean          | -48.5        |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 17           |
# |    time_elapsed         | 2651         |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0066105444 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.128       |
# |    explained_variance   | 0.809        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 767          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | 0.000359     |
# |    value_loss           | 2.16e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.9        |
# |    ep_rew_mean          | -44.1       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 18          |
# |    time_elapsed         | 2783        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.002754932 |
# |    clip_fraction        | 0.035       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.109      |
# |    explained_variance   | 0.805       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 902         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.00171     |
# |    value_loss           | 1.88e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.1        |
# |    ep_rew_mean          | -41.8       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 19          |
# |    time_elapsed         | 2922        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004519362 |
# |    clip_fraction        | 0.0485      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0999     |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 752         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.000853    |
# |    value_loss           | 1.69e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.5         |
# |    ep_rew_mean          | -31.4        |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 20           |
# |    time_elapsed         | 3053         |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0013243305 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0537      |
# |    explained_variance   | 0.863        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 811          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | 0.00182      |
# |    value_loss           | 1.58e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 17.1         |
# |    ep_rew_mean          | -3.98        |
# | time/                   |              |
# |    fps                  | 13           |
# |    iterations           | 21           |
# |    time_elapsed         | 3200         |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0018196655 |
# |    clip_fraction        | 0.0212       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.06        |
# |    explained_variance   | 0.861        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 479          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000208    |
# |    value_loss           | 1.5e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.5        |
# |    ep_rew_mean          | -14.9       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 22          |
# |    time_elapsed         | 3342        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008914383 |
# |    clip_fraction        | 0.0545      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0921     |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 357         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.00618     |
# |    value_loss           | 1.21e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 19.1       |
# |    ep_rew_mean          | -17.6      |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 23         |
# |    time_elapsed         | 3467       |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.04539534 |
# |    clip_fraction        | 0.0755     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.115     |
# |    explained_variance   | 0.91       |
# |    learning_rate        | 0.0001     |
# |    loss                 | 285        |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00532   |
# |    value_loss           | 1.1e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.2        |
# |    ep_rew_mean          | -28.9       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 24          |
# |    time_elapsed         | 3614        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009975277 |
# |    clip_fraction        | 0.0644      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.183      |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 304         |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.00776     |
# |    value_loss           | 882         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.9        |
# |    ep_rew_mean          | -23.6       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 25          |
# |    time_elapsed         | 3767        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010142341 |
# |    clip_fraction        | 0.0772      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.165      |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 434         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.0071      |
# |    value_loss           | 777         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.1        |
# |    ep_rew_mean          | -26.3       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 26          |
# |    time_elapsed         | 3906        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.012352829 |
# |    clip_fraction        | 0.0768      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.224      |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 274         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.00938     |
# |    value_loss           | 639         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.4       |
# |    ep_rew_mean          | 25.6       |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 27         |
# |    time_elapsed         | 4042       |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.02192963 |
# |    clip_fraction        | 0.119      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.365     |
# |    explained_variance   | 0.802      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 356        |
# |    n_updates            | 260        |
# |    policy_gradient_loss | 0.00813    |
# |    value_loss           | 1.49e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.2        |
# |    ep_rew_mean          | -11.2       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 28          |
# |    time_elapsed         | 4172        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.014165593 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.364      |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 308         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -5.18e-05   |
# |    value_loss           | 1.09e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.6        |
# |    ep_rew_mean          | -16.7       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 29          |
# |    time_elapsed         | 4312        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.015528407 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.415      |
# |    explained_variance   | 0.793       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 576         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.00981     |
# |    value_loss           | 1.31e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.8        |
# |    ep_rew_mean          | 18.1        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 30          |
# |    time_elapsed         | 4457        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.023257785 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.485      |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 485         |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.0108      |
# |    value_loss           | 1.29e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.1       |
# |    ep_rew_mean          | 30.1       |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 31         |
# |    time_elapsed         | 4590       |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.04616414 |
# |    clip_fraction        | 0.206      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.482     |
# |    explained_variance   | 0.881      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 536        |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.0029     |
# |    value_loss           | 1.18e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.2       |
# |    ep_rew_mean          | 34         |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 32         |
# |    time_elapsed         | 4733       |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.08728502 |
# |    clip_fraction        | 0.307      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.58      |
# |    explained_variance   | 0.697      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.33e+03   |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.0178     |
# |    value_loss           | 2.73e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.7       |
# |    ep_rew_mean          | 47.6       |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 33         |
# |    time_elapsed         | 4878       |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.02746115 |
# |    clip_fraction        | 0.229      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.594     |
# |    explained_variance   | 0.761      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 988        |
# |    n_updates            | 320        |
# |    policy_gradient_loss | 0.0102     |
# |    value_loss           | 2.08e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.79        |
# |    ep_rew_mean          | 58.9        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 34          |
# |    time_elapsed         | 5021        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.026063466 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.538      |
# |    explained_variance   | 0.851       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 972         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00478     |
# |    value_loss           | 1.9e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.82        |
# |    ep_rew_mean          | 81.5        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 35          |
# |    time_elapsed         | 5164        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.024048021 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.511      |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 759         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00584     |
# |    value_loss           | 1.97e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.09        |
# |    ep_rew_mean          | 76          |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 36          |
# |    time_elapsed         | 5301        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.053407617 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.498      |
# |    explained_variance   | 0.788       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 329         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.0126      |
# |    value_loss           | 1.16e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.76        |
# |    ep_rew_mean          | 83.3        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 37          |
# |    time_elapsed         | 5447        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.036443755 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.397      |
# |    explained_variance   | 0.759       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 791         |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00998     |
# |    value_loss           | 1.98e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.39        |
# |    ep_rew_mean          | 63.2        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 38          |
# |    time_elapsed         | 5589        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.042779975 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.452      |
# |    explained_variance   | 0.716       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 282         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.0266      |
# |    value_loss           | 1.05e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.93        |
# |    ep_rew_mean          | 82.9        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 39          |
# |    time_elapsed         | 5717        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.037766807 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.311      |
# |    explained_variance   | 0.833       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 413         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00974     |
# |    value_loss           | 1.36e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.51       |
# |    ep_rew_mean          | 83.7       |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 40         |
# |    time_elapsed         | 5868       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.02216157 |
# |    clip_fraction        | 0.14       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.271     |
# |    explained_variance   | 0.819      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 654        |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.00636    |
# |    value_loss           | 1.12e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.01        |
# |    ep_rew_mean          | 86.8        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 41          |
# |    time_elapsed         | 6013        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.028162625 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.227      |
# |    explained_variance   | 0.856       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 249         |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.0172      |
# |    value_loss           | 599         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.02        |
# |    ep_rew_mean          | 86.6        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 42          |
# |    time_elapsed         | 6155        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.034048922 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.168      |
# |    explained_variance   | 0.771       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 190         |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.0187      |
# |    value_loss           | 388         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.72        |
# |    ep_rew_mean          | 71.9        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 43          |
# |    time_elapsed         | 6307        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.036166437 |
# |    clip_fraction        | 0.0931      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.173      |
# |    explained_variance   | 0.81        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 481         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00476     |
# |    value_loss           | 480         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.77       |
# |    ep_rew_mean          | 87.8       |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 44         |
# |    time_elapsed         | 6452       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.03733912 |
# |    clip_fraction        | 0.0956     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.16      |
# |    explained_variance   | 0.846      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.52e+03   |
# |    n_updates            | 430        |
# |    policy_gradient_loss | 0.000386   |
# |    value_loss           | 1.15e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.69        |
# |    ep_rew_mean          | 88.1        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 45          |
# |    time_elapsed         | 6603        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.017448213 |
# |    clip_fraction        | 0.0603      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.13       |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 318         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00227    |
# |    value_loss           | 533         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.29       |
# |    ep_rew_mean          | 85.8       |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 46         |
# |    time_elapsed         | 6759       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.01785946 |
# |    clip_fraction        | 0.0633     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.148     |
# |    explained_variance   | 0.907      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 113        |
# |    n_updates            | 450        |
# |    policy_gradient_loss | 0.000789   |
# |    value_loss           | 363        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.16        |
# |    ep_rew_mean          | 86.1        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 47          |
# |    time_elapsed         | 6901        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.028901298 |
# |    clip_fraction        | 0.0711      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.116      |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 297         |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00165     |
# |    value_loss           | 458         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.99       |
# |    ep_rew_mean          | 81.7       |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 48         |
# |    time_elapsed         | 7053       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.02482435 |
# |    clip_fraction        | 0.0875     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.156     |
# |    explained_variance   | 0.813      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 37.2       |
# |    n_updates            | 470        |
# |    policy_gradient_loss | 0.0301     |
# |    value_loss           | 146        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.27        |
# |    ep_rew_mean          | 85.4        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 49          |
# |    time_elapsed         | 7202        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.008398298 |
# |    clip_fraction        | 0.0581      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.11       |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 42          |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00203     |
# |    value_loss           | 191         |
# -----------------------------------------

# %% [markdown]
# ### Test the Model

# %%
# Import eval policy to test agent
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# Load model from disk
model = PPO.load('./train/train_basic2/best_model_100000')

# %%
env = VizDoomGym(render=True)

# %%
# Evaluate mean reward for some games
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=100)

# %%
mean_reward

# %%
for episode in range(3):
    obs = env.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        time.sleep(0.05)
        total_reward += reward
    print('Total reward for episode {} is {}'.format(episode, total_reward))
    time.sleep(2)
# Out:
# Total reward for episode 0 is 95.0
# Total reward for episode 1 is 95.0
# Total reward for episode 2 is 95.0

# %%
env.close()
